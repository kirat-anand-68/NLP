# %%
# n-grams help us analyze th relationship between neighbour words
# N_grams= a sequence of N-tokens
#N=1 unigram
#N=2 bigram
import nltk
import pandas as pd
import matplotlib.pyplot as plt

# %%
tokens=["I","am","learning","NLP","NLP","is","great"]
bigrams=nltk.ngrams(tokens,2)
print(list(bigrams))
# Out:
# [('I', 'am'), ('am', 'learning'), ('learning', 'NLP'), ('NLP', 'NLP'), ('NLP', 'is'), ('is', 'great')]

# %%
print(tokens)
# Out:
# ['I', 'am', 'learning', 'NLP', 'NLP', 'is', 'great']

# %%
unigrams=(pd.Series(nltk.ngrams(tokens,1)).value_counts())
print(unigrams)
# Out:
# (NLP,)         2
# (I,)           1
# (am,)          1
# (learning,)    1
# (is,)          1
# (great,)       1
# Name: count, dtype: int64

# %%
unigrams[:10].sort_values().plot(kind='barh')
plt.show()

# %%
bigrams=nltk.ngrams(tokens,2)
print(list(bigrams))
# Out:
# [('I', 'am'), ('am', 'learning'), ('learning', 'NLP'), ('NLP', 'NLP'), ('NLP', 'is'), ('is', 'great')]

# %%
bigrams=pd.Series(nltk.ngrams(tokens,2)).value_counts()
print(bigrams)
bigrams[:10].sort_values().plot(kind='barh')
plt.show()
# Out:
# (I, am)            1
# (am, learning)     1
# (learning, NLP)    1
# (NLP, NLP)         1
# (NLP, is)          1
# (is, great)        1
# Name: count, dtype: int64

# %% [markdown]
# Task preprocessing

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer,PorterStemmer
import re
import pandas as pd

# %%
data=pd.read_csv("tripadvisor_hotel_reviews.csv")

# %%
data.head()
# Out:
#                                               Review  Rating
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 109 entries, 0 to 108
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Review  109 non-null    object
#  1   Rating  109 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 1.8+ KB

# %%
data['Review'][0]
# Out:
# 'nice hotel expensive parking got good deal stay hotel anniversary, arrived late evening took advice previous reviews did valet parking, check quick easy, little disappointed non-existent view room room clean nice size, bed comfortable woke stiff neck high pillows, not soundproof like heard music room night morning loud bangs doors opening closing hear people talking hallway, maybe just noisy neighbors, aveda bath products nice, did not goldfish stay nice touch taken advantage staying longer, location great walking distance shopping, overall nice experience having pay 40 parking night,  '

# %%
data['review_lowercase']=data['Review'].str.lower()

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...

# %%
en_stopwords=set(stopwords.words('english'))

# %%
en_stopwords.remove('no')

# %%
data['review_no_stopwords']=data['review_lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))

# %%
data['review_no_stopwords'][0]
# Out:
# 'nice hotel expensive parking got good deal stay hotel anniversary, arrived late evening took advice previous reviews valet parking, check quick easy, little disappointed non-existent view room room clean nice size, bed comfortable woke stiff neck high pillows, soundproof like heard music room night morning loud bangs doors opening closing hear people talking hallway, maybe noisy neighbors, aveda bath products nice, goldfish stay nice touch taken advantage staying longer, location great walking distance shopping, overall nice experience pay 40 parking night,'

# %%
## removing the punctuation
data['review_no_stopwords_no_punct']=data.apply(lambda x: re.sub(r'[*]','star',x['review_no_stopwords']),axis=1)

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms 4* experience hotel monaco seattle ...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
data['review_no_stopwords_no_punct']=data.apply(lambda x: re.sub(r"[^\w\s]","",x['review_no_stopwords_no_punct']),axis=1)

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms 4* experience hotel monaco seattle ...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
#tokenize
data['tokens']=data.apply(lambda x: word_tokenize(x['review_no_stopwords_no_punct']),axis=1)

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms 4* experience hotel monaco seattle ...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
data['tokens'][0]
# Out:
# ['nice',
#  'hotel',
#  'expensive',
#  'parking',
#  'got',
#  'good',
#  'deal',
#  'stay',
#  'hotel',
#  'anniversary',
#  'arrived',
#  'late',
#  'evening',
#  'took',
#  'advice',
#  'previous',
#  'reviews',
#  'valet',
#  'parking',
#  'check',
#  'quick',
#  'easy',
#  'little',
#  'disappointed',
#  'nonexistent',
#  'view',
#  'room',
#  'room',
#  'clean',
#  'nice',
#  'size',
#  'bed',
#  'comfortable',
#  'woke',
#  'stiff',
#  'neck',
#  'high',
#  'pillows',
#  'soundproof',
#  'like',
#  'heard',
#  'music',
#  'room',
#  'night',
#  'morning',
#  'loud',
#  'bangs',
#  'doors',
#  'opening',
#  'closing',
#  'hear',
#  'people',
#  'talking',
#  'hallway',
#  'maybe',
#  'noisy',
#  'neighbors',
#  'aveda',
#  'bath',
#  'products',
#  'nice',
#  'goldfish',
#  'stay',
#  'nice',
#  'touch',
#  'taken',
#  'advantage',
#  'staying',
#  'longer',
#  'location',
#  'great',
#  'walking',
#  'distance',
#  'shopping',
#  'overall',
#  'nice',
#  'experience',
# ...

# %%
ps=PorterStemmer()

# %%
data['stemmed']=data['tokens'].apply(lambda tokens: [ps.stem(token) for token in tokens])

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms 4* experience hotel monaco seattle ...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
data['lemmatized']=data['tokens'].apply(lambda tokens: [WordNetLemmatizer().lemmatize(token) for token in tokens])

# %%
data['lemmatized'][0]
# Out:
# ['nice',
#  'hotel',
#  'expensive',
#  'parking',
#  'got',
#  'good',
#  'deal',
#  'stay',
#  'hotel',
#  'anniversary',
#  'arrived',
#  'late',
#  'evening',
#  'took',
#  'advice',
#  'previous',
#  'review',
#  'valet',
#  'parking',
#  'check',
#  'quick',
#  'easy',
#  'little',
#  'disappointed',
#  'nonexistent',
#  'view',
#  'room',
#  'room',
#  'clean',
#  'nice',
#  'size',
#  'bed',
#  'comfortable',
#  'woke',
#  'stiff',
#  'neck',
#  'high',
#  'pillow',
#  'soundproof',
#  'like',
#  'heard',
#  'music',
#  'room',
#  'night',
#  'morning',
#  'loud',
#  'bang',
#  'door',
#  'opening',
#  'closing',
#  'hear',
#  'people',
#  'talking',
#  'hallway',
#  'maybe',
#  'noisy',
#  'neighbor',
#  'aveda',
#  'bath',
#  'product',
#  'nice',
#  'goldfish',
#  'stay',
#  'nice',
#  'touch',
#  'taken',
#  'advantage',
#  'staying',
#  'longer',
#  'location',
#  'great',
#  'walking',
#  'distance',
#  'shopping',
#  'overall',
#  'nice',
#  'experience',
#  'pay',
# ...

# %%
data.head()
# Out:
#                                               Review  Rating  \
# 0  nice hotel expensive parking got good deal sta...       4
# 1  ok nothing special charge diamond member hilto...       2
# 2  nice rooms not 4* experience hotel monaco seat...       3
# 3  unique, great stay, wonderful time hotel monac...       5
# 4  great stay great stay, went seahawk game aweso...       5
#
#                                     review_lowercase  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms not 4* experience hotel monaco seat...
# 3  unique, great stay, wonderful time hotel monac...
# 4  great stay great stay, went seahawk game aweso...
#
#                                  review_no_stopwords  \
# 0  nice hotel expensive parking got good deal sta...
# 1  ok nothing special charge diamond member hilto...
# 2  nice rooms 4* experience hotel monaco seattle ...
# 3  unique, great stay, wonderful time hotel monac...
# ...

# %%
tokens_clean=sum(data['lemmatized'],[])
# when we use the sum in the python it join one by one

# %%
unigrams=pd.Series(nltk.ngrams(tokens_clean,1)).value_counts()

# %%
print(unigrams)
# Out:
# (hotel,)           292
# (room,)            275
# (great,)           126
# (stay,)             95
# (staff,)            90
#                   ...
# (australian,)        1
# (australiaour,)      1
# (exception,)         1
# (nightyou,)          1
# (swiss,)             1
# Name: count, Length: 2589, dtype: int64

# %%
bigrams=pd.Series(nltk.ngrams(tokens_clean,2)).value_counts()
print(bigrams)
# Out:
# (great, location)          24
# (space, needle)            21
# (hotel, monaco)            16
# (staff, friendly)          13
# (pike, place)              12
#                            ..
# (looking, decorated)        1
# (decorated, maintained)     1
# (maintained, staff)         1
# (professional, large)       1
# (map, hopefully)            1
# Name: count, Length: 8223, dtype: int64
