# %%
sentence='My name is kirat'

# %%
sentence_lower=sentence.lower()
print(sentence_lower)
# Out:
# my name is kirat

# %%
sentence_list=['Could you pass me the TV remote?', 'The weather is nice today.', 'I love programming in Python.']

# %%
lower_sentences = [s.lower() for s in sentence_list]
print(lower_sentences)
# Out:
# ['could you pass me the tv remote?', 'the weather is nice today.', 'i love programming in python.']

# %%
##REMOVING STOPWORDS
from nltk.corpus import stopwords

# %%
en_stopwords=stopwords.words('english')

# %%
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
sentence='it was too far to go to the shop and he did not want her to walk'

# %%
sentence_no_stopwords=' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(en_stopwords)
# Out:
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 's
# ...

# %%
print(sentence_no_stopwords)
# Out:
# far go shop want walk

# %%
en_stopwords.remove('did')
en_stopwords.remove('not')

# %%
en_stopwords.append('go')

# %%
sentence_no_stopwords_new=' '.join([word for word in sentence.split() if word not in en_stopwords])

# %%
print(sentence_no_stopwords_new)
# Out:
# far shop did not want walk

# %%
##REGEX
import re
text="Hello!!! This is Kirat123. Welcome to NLP @ OpenAI."
cleaned_text=re.sub(r'[^a-zA-Z\s]', '', text)
print(cleaned_text)
# Out:
# Hello This is Kirat Welcome to NLP  OpenAI

# %%
#\n-new_line
#r'\n'-raw_string
my_folder=r'C:\desktop\notes'
print(my_folder)
# Out:
# C:\desktop\notes

# %%
#result_search=re.search("pattern",'string to be searched')

# %%
result_search=re.search("NLP",r"I am learning  NLP")

# %%
print(result_search)
# Out:
# <re.Match object; span=(15, 18), match='NLP'>

# %%
#re.sub(pattern, replacement, string)
result_sub=re.sub(r'NLP','Natural Language Processing',r'I am learning NLP')
print(result_sub)
# Out:
# I am learning Natural Language Processing

# %%
#r^a -- string starts with a
#r'a$' -- string ends with a
customer_reviews=[
    "sam was a grets help to me in the storte",
    "the Cashier was rude to me , I thinh her name was eleanor",
    "amazing wirk from sadeen !",
    "sarah was able to help me find the items I needed quickly",
    "lucy is such a great addition to the team",
    "great service from sara she found me what i wanted"]

# %%
a_review=[]
pattern_to_find= r"^a"

for string in customer_reviews:
    if(re.search(pattern_to_find ,string)):
        a_review.append(string)

# %%
print(a_review)
# Out:
# ['amazing wirk from sadeen !']

# %%
# review ends with teh letter y
y_review=[]
pattern_to_find= r"y$"

for string in customer_reviews:
    if(re.search(pattern_to_find ,string)):
        y_review.append(string)

# %%
print(y_review)
# Out:
# ['sarah was able to help me find the items I needed quickly']

# %%
# match either neede or wanted "r(need|want)ed"
needwant_review=[]
pattern_to_find= r"(need|want)ed"

for string in customer_reviews:
    if(re.search(pattern_to_find ,string)):
        needwant_review.append(string)

# %%
print(needwant_review)
# Out:
# ['sarah was able to help me find the items I needed quickly', 'great service from sara she found me what i wanted']

# %%
#removing thepuncuation from the text
no_punct_reviews=[]
pattern_to_find=r'[^\w\s]'
#^ not \w word characters \s space characters
# it means that find anything but not the word charcter as not the punctuations
for string in customer_reviews:
    no_punct_string=re.sub(pattern_to_find,'',string)
    no_punct_reviews.append(no_punct_string)

# %%
print(no_punct_reviews)
# Out:
# ['sam was a grets help to me in the storte', 'the Cashier was rude to me  I thinh her name was eleanor', 'amazing wirk from sadeen ', 'sarah was able to help me find the items I needed quickly', 'lucy is such a great addition to the team', 'great service from sara she found me what i wanted']

# %%
data['review_no_stopwords']=data['Review_lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 data['review_no_stopwords']=data['Review_lowercase'].apply(lambda x: ' '.join([word for word in x.split() if word not in (en_stopwords)]))
#
# NameError: name 'data' is not defined
